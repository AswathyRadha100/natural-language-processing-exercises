# %% [markdown]
# <div style="background-color: lightblue; padding: 60px;">
#     <h1><b>NLP - Prepare
# </b></h1>
# </div>

# %%
# Run it once 
#nltk.download('wordnet')
#nltk.download('omw-1.4')
#nltk.download('stopwords')

# %%
import unicodedata
import re
import json

import nltk
from nltk.tokenize.toktok import ToktokTokenizer
from nltk.corpus import stopwords

import pandas as pd

import acquire as a

import prepare as p
# Out:
# Grabbing contents for business.
# Time to grab contents of business: 0.87 seconds
# Grabbing contents for entertainment.
# Time to grab contents of entertainment: 0.84 seconds
# Grabbing contents for technology.
# Time to grab contents of technology: 1.06 seconds
# Grabbing contents for sports.
# Time to grab contents of sports: 2.77 seconds
# Job finished!
# It took 0.09 minutes to execute scraping

# %% [markdown]
# ## Exercises

# %% [markdown]
# In this lesson we'll take our acquired data and parse it, that is, we'll better understand the text data by breaking it down into smaller components.
#
# In this exercise we will be defining some functions to prepare textual data. These functions should apply equally well to both the codeup blog articles and the news articles that were previously acquired.

# %% [markdown]
# 1. Define a function named basic_clean. It should take in a string and apply some basic text cleaning to it:
#
#  - Lowercase everything
#  - Normalize unicode characters
#  - Replace anything that is not a letter, number, whitespace or a single quote.

# %%
article = "Coming into our Data Science program, you will need to know some math and \
stats. However, many of our applicants actually learn in the application process – you \
don’t need to be an expert before applying! Data science is a very accessible field to \
anyone dedicated to learning new skills, and we can work with any applicant to help them \
learn what they need to know. But what “skills” do we mean, exactly? Just what exactly \
are the data science math and stats principles you need to know?', 'What are the main \
math principles you need to know to get into Codeup’s Data Science program?'"
article
# Out:
# "Coming into our Data Science program, you will need to know some math and stats. However, many of our applicants actually learn in the application process – you don’t need to be an expert before applying! Data science is a very accessible field to anyone dedicated to learning new skills, and we can work with any applicant to help them learn what they need to know. But what “skills” do we mean, exactly? Just what exactly are the data science math and stats principles you need to know?', 'What are the main math principles you need to know to get into Codeup’s Data Science program?'"

# %% [markdown]
# Note:-
#
#     -  NFKD (Normalization Form Compatibility Decomposition)
#
#     -  ASCII (American Standard Code for Information Interchange)
#
#     - ASCII includes: all punctuation, numbers and A-Z -- There are 256 ASCII characters
#
# Basically: the overall purpose of this syntax is to take an input string (original), normalize it, remove any diacritical marks, and convert it to a string containing only ASCII characters. Any non-ASCII characters are removed from the final output.

# %% [markdown]
# Note:-
#
# r' : indicates raw string
# ^ : not including (negates the pattern)
# a-z : any letter
# 0-9 : any number
# Basically, this regex statement means, anything that is not a lowercase letter or a number. Leaving only lowercase letters, digits, and whitespace characters in the output

# %%
def basic_clean(text):
    '''
    This function takes in a string and returns the string normalized.
    '''
    # Lowercase everything
    text = text.lower()
    # Normalize unicode characters
    text = unicodedata.normalize('NFKD', text)\
        .encode('ascii', 'ignore')\
        .decode('utf-8', 'ignore')
    # Remove anything that is not a letter, number, or whitespace
    text = re.sub(r"[^a-z0-9\s]", '', text)
    return text

# %%
article_clean = basic_clean(article)
article_clean
# Out:
# 'coming into our data science program you will need to know some math and stats however many of our applicants actually learn in the application process  you dont need to be an expert before applying data science is a very accessible field to anyone dedicated to learning new skills and we can work with any applicant to help them learn what they need to know but what skills do we mean exactly just what exactly are the data science math and stats principles you need to know what are the main math principles you need to know to get into codeups data science program'

# %%
#testing the function in prepare.py
article_clean_p = p.basic_clean(article)
article_clean_p
# Out:
# 'coming into our data science program you will need to know some math and stats however many of our applicants actually learn in the application process  you dont need to be an expert before applying data science is a very accessible field to anyone dedicated to learning new skills and we can work with any applicant to help them learn what they need to know but what skills do we mean exactly just what exactly are the data science math and stats principles you need to know what are the main math principles you need to know to get into codeups data science program'

# %% [markdown]
# 2. Define a function named tokenize. It should take in a string and tokenize all the words in the string.

# %%
def tokenize(text):
    '''
    This function takes in a string and returns it tokenized.
    '''
    # Create the tokenizer
    tokenizer = nltk.tokenize.ToktokTokenizer()
    # Use the tokenizer
    text = tokenizer.tokenize(text, return_str=True)
    return text

# %%
article_tokens = tokenize(article_clean)
article_tokens
# Out:
# 'coming into our data science program you will need to know some math and stats however many of our applicants actually learn in the application process you dont need to be an expert before applying data science is a very accessible field to anyone dedicated to learning new skills and we can work with any applicant to help them learn what they need to know but what skills do we mean exactly just what exactly are the data science math and stats principles you need to know what are the main math principles you need to know to get into codeups data science program'

# %%
#testing the function in prepare.py

article_tokens_p = p.tokenize(article_clean_p)
article_tokens_p
# Out:
# 'coming into our data science program you will need to know some math and stats however many of our applicants actually learn in the application process you dont need to be an expert before applying data science is a very accessible field to anyone dedicated to learning new skills and we can work with any applicant to help them learn what they need to know but what skills do we mean exactly just what exactly are the data science math and stats principles you need to know what are the main math principles you need to know to get into codeups data science program'

# %% [markdown]
# ### NOTE:
#
# Step to tokenize:
#
# Create the tokenizer
# Use the tokenizer
# Now, instead of a block of text, we have a list of individual words.

# %% [markdown]
# 3. Define a function named stem. It should accept some text and return the text after applying stemming to all the words.

# %%
def stem(text):
    '''
    This function takes in a string and returns it stemmed.
    '''
    # Create the porter stemmer
    ps = nltk.porter.PorterStemmer()
    # Use the stemmer on each token
    stems = [ps.stem(word) for word in text.split()]
    # Join the stemmed list of words back into a string
    article_stemmed = ' '.join(stems)
    return article_stemmed, stems

# %%
article_stemmed, stems = stem(article_tokens)
article_stemmed
# Out:
# 'come into our data scienc program you will need to know some math and stat howev mani of our applic actual learn in the applic process you dont need to be an expert befor appli data scienc is a veri access field to anyon dedic to learn new skill and we can work with ani applic to help them learn what they need to know but what skill do we mean exactli just what exactli are the data scienc math and stat principl you need to know what are the main math principl you need to know to get into codeup data scienc program'

# %%
pd.Series(stems).value_counts().head(10)
# Out:
# to        9
# need      5
# data      4
# scienc    4
# you       4
# what      4
# know      4
# applic    3
# the       3
# math      3
# Name: count, dtype: int64

# %%
article_stemmed, p.stems = p.stem(article_tokens_p)
article_stemmed
# Out:
# 'come into our data scienc program you will need to know some math and stat howev mani of our applic actual learn in the applic process you dont need to be an expert befor appli data scienc is a veri access field to anyon dedic to learn new skill and we can work with ani applic to help them learn what they need to know but what skill do we mean exactli just what exactli are the data scienc math and stat principl you need to know what are the main math principl you need to know to get into codeup data scienc program'

# %% [markdown]
# 4. Define a function named lemmatize. It should accept some text and return the text after applying lemmatization to each word.

# %%
def lemmatize(text):
    '''
    This function takes in a string and returns it lemmatized.
    '''
    # Create the Lemmatizer.
    wnl = nltk.stem.WordNetLemmatizer()
    # Use the lemmatizer on each token
    lemmas = [wnl.lemmatize(word) for word in text.split()]
    # Join the lemmatized list of words back into a string
    article_lemmatized = ' '.join(lemmas)
    return article_lemmatized, lemmas

# %%
article_lemmatized, lemmas = lemmatize(article_tokens)

# %%
pd.Series(lemmas).value_counts().head(10)
# Out:
# to         9
# need       5
# what       4
# data       4
# science    4
# you        4
# know       4
# the        3
# math       3
# and        3
# Name: count, dtype: int64

# %%
article_lemmatized, lemmas = p.lemmatize(article_tokens_p)
pd.Series(lemmas).value_counts().head(10)
# Out:
# to         9
# need       5
# what       4
# data       4
# science    4
# you        4
# know       4
# the        3
# math       3
# and        3
# Name: count, dtype: int64

# %% [markdown]
# 5. Define a function named remove_stopwords. It should accept some text and return the text after removing all the stopwords.
#
# - This function should define two optional parameters, extra_words and exclude_words. These parameters should define any additional stop words to include, and any words that we don't want to remove.

# %%
def remove_stopwords(text, extra_words=[], exclude_words=[]):
    '''
    This function takes in a string and returns it after removing stopwords.
    '''
    # Create stopword_list
    stopword_list = stopwords.words('english')
    # Remove 'exclude_words' from stopword_list to keep these in the text
    stopword_list = set(stopword_list) - set(exclude_words)
    # Add in 'extra_words' to stopword_list
    stopword_list = stopword_list.union(set(extra_words))
    # Split words in textstr
    words = text.split()
    # Create a list of words from my string with stopwords removed and assign to variable
    filtered_words = [w for w in words if w not in stopword_list]
    # Join words in the list back into strings and assign to a variable
    article_without_stopwords = ' '.join(filtered_words)
    return article_without_stopwords

# %%
article_without_stopwords = remove_stopwords(article_lemmatized)
print(article_without_stopwords)
# Out:
# coming data science program need know math stats however many applicant actually learn application process dont need expert applying data science accessible field anyone dedicated learning new skill work applicant help learn need know skill mean exactly exactly data science math stats principle need know main math principle need know get codeups data science program

# %%
#testing the function in prepare.py

article_without_stopwords = p.remove_stopwords(article_lemmatized)
print(article_without_stopwords)
# Out:
# coming data science program need know math stats however many applicant actually learn application process dont need expert applying data science accessible field anyone dedicated learning new skill work applicant help learn need know skill mean exactly exactly data science math stats principle need know main math principle need know get codeups data science program

# %% [markdown]
# 6. Use your data from the acquire to produce a dataframe of the news articles. Name the dataframe news_df.

# %%
base_url = 'https://inshorts.com/en/read/'
categories = [
    'business',
    'entertainment',
    'technology',
    'sports'
]

news_df = a.scrape_news_articles(categories, base_url)
news_df.head()
# Out:
# Grabbing contents for business.
# Time to grab contents of business: 2.83 seconds
# Grabbing contents for entertainment.
# Time to grab contents of entertainment: 0.89 seconds
# Grabbing contents for technology.
# Time to grab contents of technology: 0.82 seconds
# Grabbing contents for sports.
# Time to grab contents of sports: 1.37 seconds
# Job finished!
# It took 0.1 minutes to execute scraping
#                                                title  \
# 0  Astrotalk eyes Rs 600 cr in revenues, preps ne...
# 1  Kenneth Griffin to build one of the world's mo...
# 2  Huda Beauty faces boycott calls after Founder ...
# 3  Bank of Baroda suspends 60 employees over app ...
# 4  Tata Group to invest another $1 bn in Tata Dig...
#
#                                                 body  category
# 0  Astrotalk, an app for astrology, is expanding ...  business
# 1  Kenneth Griffin, America's billionaire hedge f...  business
# 2  Cosmetics brand Huda Beauty is facing calls fo...  business
# ...

# %% [markdown]
# 7. Make another dataframe for the Codeup blog posts. Name the dataframe codeup_df.

# %%
blog_links = ['https://codeup.edu/featured/apida-heritage-month/',
 'https://codeup.edu/featured/women-in-tech-panelist-spotlight/',
 'https://codeup.edu/featured/women-in-tech-rachel-robbins-mayhill/',
 'https://codeup.edu/codeup-news/women-in-tech-panelist-spotlight-sarah-mellor/',
 'https://codeup.edu/events/women-in-tech-madeleine/',
 'https://codeup.edu/codeup-news/panelist-spotlight-4/']
codeup_df = a.scrape_blog_articles(blog_links)

codeup_df.head()
# Out:
#                                                title  \
# 0  Spotlight on APIDA Voices: Celebrating Heritag...
# 1  Women in tech: Panelist Spotlight – Magdalena ...
# 2  Women in tech: Panelist Spotlight – Rachel Rob...
# 3   Women in Tech: Panelist Spotlight – Sarah Mellor
# 4  Women in Tech: Panelist Spotlight – Madeleine ...
#
#                                              article
# 0  May is traditionally known as Asian American a...
# 1  Women in tech: Panelist Spotlight – Magdalena ...
# 2  Women in tech: Panelist Spotlight – Rachel Rob...
# 3  Women in tech: Panelist Spotlight – Sarah Mell...
# 4  Women in tech: Panelist Spotlight – Madeleine ...

# %% [markdown]
# 8. For each dataframe, produce the following columns:
#
#  - title to hold the title
#  - original to hold the original article/post content
#  - clean to hold the normalized and tokenized original with the stopwords removed.
#  - stemmed to hold the stemmed version of the cleaned data.
#  - lemmatized to hold the lemmatized version of the cleaned data.

# %%
# rename article column to original
news_df.rename(columns={'body': 'original'}, inplace=True)
codeup_df.rename(columns={'article': 'original'}, inplace=True)

# add 'clean' column to each df
news_df['clean'] = news_df.original.apply(basic_clean).apply(tokenize).apply(remove_stopwords)
codeup_df['clean'] = codeup_df.original.apply(basic_clean).apply(tokenize).apply(remove_stopwords)

# add 'stemmed' column to each df
news_df['stemmed'] = news_df.clean.apply(stem)
codeup_df['stemmed'] = codeup_df.clean.apply(stem)

# add 'lemmatized' column to each df
news_df['lemmatized'] = news_df.clean.apply(lemmatize)
codeup_df['lemmatized'] = codeup_df.clean.apply(lemmatize)

news_df.head()
# Out:
#                                                title  \
# 0  Astrotalk eyes Rs 600 cr in revenues, preps ne...
# 1  Kenneth Griffin to build one of the world's mo...
# 2  Huda Beauty faces boycott calls after Founder ...
# 3  Bank of Baroda suspends 60 employees over app ...
# 4  Tata Group to invest another $1 bn in Tata Dig...
#
#                                             original  category  \
# 0  Astrotalk, an app for astrology, is expanding ...  business
# 1  Kenneth Griffin, America's billionaire hedge f...  business
# 2  Cosmetics brand Huda Beauty is facing calls fo...  business
# 3  Bank of Baroda has reportedly suspended around...  business
# 4  Tata Group is weighing investing another $1 bi...  business
#
#                                                clean  \
# 0  astrotalk app astrology expanding business men...
# 1  kenneth griffin americas billionaire hedge fun...
# 2  cosmetics brand huda beauty facing calls boyco...
# ...

# %%
codeup_df.head()
# Out:
#                                                title  \
# 0  Spotlight on APIDA Voices: Celebrating Heritag...
# 1  Women in tech: Panelist Spotlight – Magdalena ...
# 2  Women in tech: Panelist Spotlight – Rachel Rob...
# 3   Women in Tech: Panelist Spotlight – Sarah Mellor
# 4  Women in Tech: Panelist Spotlight – Madeleine ...
#
#                                             original  \
# 0  May is traditionally known as Asian American a...
# 1  Women in tech: Panelist Spotlight – Magdalena ...
# 2  Women in tech: Panelist Spotlight – Rachel Rob...
# 3  Women in tech: Panelist Spotlight – Sarah Mell...
# 4  Women in tech: Panelist Spotlight – Madeleine ...
#
#                                                clean  \
# 0  may traditionally known asian american pacific...
# 1  women tech panelist spotlight magdalena rahn c...
# 2  women tech panelist spotlight rachel robbinsma...
# 3  women tech panelist spotlight sarah mellor cod...
# ...

# %%
#testing the function in prepare.py

news_df = p.wrangle_news()
# Out:
# Grabbing contents for business.
# Time to grab contents of business: 0.1 seconds
# Grabbing contents for entertainment.
# Time to grab contents of entertainment: 0.28 seconds
# Grabbing contents for technology.
# Time to grab contents of technology: 0.18 seconds
# Grabbing contents for sports.
# Time to grab contents of sports: 0.09 seconds
# Job finished!
# It took 0.01 minutes to execute scraping

# %%
news_df
# Out:
#                                                 title  \
# 0   Astrotalk eyes Rs 600 cr in revenues, preps ne...
# 1   Kenneth Griffin to build one of the world's mo...
# 2   Huda Beauty faces boycott calls after Founder ...
# 3   Bank of Baroda suspends 60 employees over app ...
# 4   Tata Group to invest another $1 bn in Tata Dig...
# 5              Malaysian ringgit falls to 25-year low
# 6   Google launches credit services for consumers ...
# 7     Microsoft India’s revenues climb 39% to $2.3 bn
# 8   We'll continue hiring, will 1st honour offers ...
# 9   AirAsia CEO Tony shares pic of outdoor BBQ aft...
# 10  A lot of my casual girlfriends attended my wed...
# 11  Regret dropping out of college over depression...
# 12  Pic shows Aamir Khan's son Junaid Khan's trans...
# 13  I was seen only as saree-clad Indian character...
# 14  Not easy to live up to expectations: Vivek on ...
# 15  Aamir said if Dangal flops, he'll teach people...
# ...

# %%
#testing the function in prepare.py

codeup_df = p.wrangle_codeup_blog()

# %%
codeup_df
# Out:
#                                                title  \
# 0  Spotlight on APIDA Voices: Celebrating Heritag...
# 1  Women in tech: Panelist Spotlight – Magdalena ...
# 2  Women in tech: Panelist Spotlight – Rachel Rob...
# 3   Women in Tech: Panelist Spotlight – Sarah Mellor
# 4  Women in Tech: Panelist Spotlight – Madeleine ...
# 5  Black Excellence in Tech: Panelist Spotlight –...
#
#                                             original  \
# 0  May is traditionally known as Asian American a...
# 1  Women in tech: Panelist Spotlight – Magdalena ...
# 2  Women in tech: Panelist Spotlight – Rachel Rob...
# 3  Women in tech: Panelist Spotlight – Sarah Mell...
# 4  Women in tech: Panelist Spotlight – Madeleine ...
# 5  Black excellence in tech: Panelist Spotlight –...
#
#                                                clean  \
# 0  may traditionally known asian american pacific...
# 1  women tech panelist spotlight magdalena rahn c...
# ...

# %% [markdown]
# 9. Ask yourself:
#
#  - If your corpus is 493KB, would you prefer to use stemmed or lemmatized text?
#  - If your corpus is 25MB, would you prefer to use stemmed or lemmatized text?
#  - If your corpus is 200TB of text and you're charged by the megabyte for your hosted computational resources, would you prefer to use stemmed or lemmatized text?

# %% [markdown]
#  - In a small corpus (493KB), lemmatization is preferable because it provides more linguistically accurate results by reducing words to their base form.
#
#  - Medium-sized corpus (25MB), lemmatization is still favored because it balances accuracy and computational efficiency, providing meaningful results without overly taxing resources.
#
#  - In a massive corpus of 200TB, stemming is preferred due to computational efficiency. Stemming simplifies words to their root forms, which reduces the processing load, crucial in a cost-sensitive, resource-intensive environment.
